# %% [markdown]
# <a href="https://colab.research.google.com/github/dimanchief13-spec/Univercity/blob/main/Tasks/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5%203%20%22%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%963_%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B2_%D0%9E%D0%9E%D0%9F_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа №3. Введение в ООП**

# %% [markdown]
# ## **Задание №1. Создайте класс Sphere для представления сферы в трехмерном пространстве**

# %% [markdown]
# Обеспечьте следующие методы класса:
#
# 1. Конструктор, принимающий 4 действительных числа: радиус, и 3 координаты центра шара. Если конструктор вызывается без аргументов, создать объект сферы с единичным радиусом и центром в начале координат. Если конструктор вызывается с аргументом, создать объект сферы с соответствующим радиусом и центром в начале координат.
#
# 2. Метод get_volume (), который возвращает действительное число — объем шара, ограниченной текущей сферой.
#
# 3. Метод get_square (), который возвращает действительное число — площадь внешней поверхности сферы.
#
# 4. Метод get_radius (), который возвращает действительное число — радиус сферы.
#
# 5. Метод get_center (), который возвращает тьюпл с 3 действительными числами — координатами центра сферы в том же порядке, в каком они задаются в конструкторе.
#
# 6. Метод set_radius (r), который принимает 1 аргумент — действительное число, и меняет радиус текущей сферы, ничего не возвращая.
#
# 7. Метод set_center (x, y, z), который принимает 3 аргумента — действительных числа, и меняет координаты центра сферы, ничего не возвращая. Координаты задаются в том же порядке, что и в конструкторе.
#
# 8. Метод is_point_inside (x, y, z), который принимает 3 аргумента — действительных числа — координаты некоторой точки в пространстве (в том же порядке, что и в конструкторе), и возвращает логическое значение True или False в зависимости от того, находится эта точка внутри сферы.

# %%
class Sphere:
  def __init__(self, radius = 1, x = 0, y = 0, z = 0):
    self.radius = float(radius)
    self.x = float(x)
    self.y = float(y)
    self.z = float(z)


  def get_volume(self):
    return 4/3 * 3.1415 * self.radius**3

  def get_square(self):
    return 4 * 3.1415 * self.radius**2

  def get_radius(self):
    return self.radius

  def get_center(self):
    return (self.x, self.y, self.z)

  def set_radius(self, r):
    self.radius = float(r)

  def set_center (self, x, y, z):
    self.x = float(x)
    self.y = float(y)
    self.z = float(z)

  def is_point_inside(self, x, y, z):
    d = ((x - self.x)**2 + (y - self.y)**2 + (z - self.z)**2)**1/2
    if d > self.radius:
      return False
    else:
      return True

# %%
# Тесты

s0 = Sphere(0.5) # test sphere creation with radius and default center
print(s0.get_center()) # (0.0, 0.0, 0.0)
print(s0.get_volume()) # 0.523598775598
print(s0.is_point_inside(0 , -1.5, 0)) # False
s0.set_radius(1.6)
print(s0.is_point_inside(0, -1.5, 0)) # True
print(s0.get_radius()) # 1.6
# Out:
# (0.0, 0.0, 0.0)
# 0.5235833333333333
# False
# True
# 1.6

# %% [markdown]
# ## **Задание №2. Создайте класс SuperStr, который наследует стандартный класс str и содержит 2 новых метода:**

# %% [markdown]
# 1. Метод is_repeatance (s), который принимает 1 аргумент s и возвращает True или False в зависимости от того, может ли текущая строку быть получена целым количеством повторов строки s. Вернуть False, если s не является строкой. Считать, что пустая строка не содержит повторов.
#
# 2. Метод is_palindrom (), который возвращает True или False в зависимости от того, является ли строка [палиндромом](https://ru.wikipedia.org/wiki/Палиндром). Регистрами символов пренебрегать. Пустую строку считать палиндромом.

# %%
class SuperStr(str):
  def __init__(self, user_input):
    self.user_input = user_input

  def is_repeatance(self, s):
    try:
      rep = len(self.user_input) // len(s)
      return self.user_input == s * rep
    except TypeError:
      return False


  def is_palindrom(self):
    try:
      normalize = ''.join(i.lower() for i in self.user_input)
      return normalize == normalize[::-1]
    except TypeError:
      return False

# %%
# Тесты

s = SuperStr("123123123123")
print(s.is_repeatance("123")) # True
print(s.is_repeatance("123123")) # True
print(s.is_repeatance("123123123123")) # True
print(s.is_repeatance("12312")) # False
print(s.is_repeatance(123)) # False
print(s.is_palindrom()) # False
print(s) # 123123123123 (строка)
print(int(s)) # 123123123123 (целое число)
print(s + "qwe") # 123123123123qwe
p = SuperStr("123_321")
print(p.is_palindrom()) # True
# Out:
# True
# True
# True
# False
# False
# False
# 123123123123
# 123123123123
# 123123123123qwe
# True

# %% [markdown]
# ## **Задание №3. В коде ниже представлен класс преподавателей и класс студентов (вы можете взять этот код за основу или написать свой).**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.courses_in_progress.append(course_name)

    def add_finished_courses(self, course_name):
      self.finished_courses.append(course_name)

    def rate_lecturer(self, lecturer, course_name, rating):

      if course_name not in self.courses_in_progress:
          print(f"Ошибка: Студент {self.name} {self.surname} не записан на курс '{course_name}'.")
          return

      if course_name not in lecturer.courses_attached:
          print(f"Ошибка: Лектор {lecturer.name} {lecturer.surname} не ведет курс '{course_name}'.")
          return

      if not 1 <= rating <= 10:
          print("Ошибка: Оценка должна быть от 1 до 10.")
          return

      if course_name not in lecturer.rating:
          lecturer.rating[course_name] = []

      lecturer.rating[course_name].append(rating)


      print(f"Студент {self.name} {self.surname} поставил лектору {lecturer.surname} оценку {rating} по курсу '{course_name}'.")

    def __str__(self):
      grades_sum = 0
      grades_count = 0
      for course_grades in self.grades.values():
        grades_sum += sum(course_grades)
        grades_count += len(course_grades)

      avg_grades = grades_sum / grades_count if grades_count > 0 else 0.0
      formatted_avg_grades = f"{avg_grades:.1f}"

      courses_in_progress_str = ", ".join(self.courses_in_progress)
      finished_courses_str = ", ".join(self.finished_courses)

      return (f"Имя: {self.name}\n"
              f"Фамилия: {self.surname}\n"
              f"Средняя оценка за домашние задания: {formatted_avg_grades}\n"
              f"Курсы в процессе изучения: {courses_in_progress_str}\n"
              f"Завершенные курсы: {finished_courses_str}")


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def __str__(self):
      return f'Имя: {self.name}\nФамилия: {self.surname}'

# %%
best_student = Student('Ruoy', 'Eman', 'your_gender')

# %% [markdown]
# ### **3.1. Наследование**

# %% [markdown]
# * Класс Mentor должен стать родительским классом для преподавателей. От него нужно реализовать наследование классов Lecturer (лекторы) и Reviewer (эксперты, проверяющие домашние задания).
#
# > Имя, фамилю и список закрепленных курсов логично реализовать на уровне родительского класса.

# %%
class Lecturer(Mentor):
  def __init__(self, name, surname, rating):
    super().__init__(name, surname)
    self.rating = {}

  def get_avg_grade(self):
    grades_sum = 0
    grades_count = 0
    for course_grades in self.rating.values():
        grades_sum += sum(course_grades)
        grades_count += len(course_grades)

    avg_rating = grades_sum / grades_count if grades_count > 0 else 0.0
    formatted_avg_rating = f"{avg_rating:.1f}"
    return float(formatted_avg_rating)

  def __str__(self):

    return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {self.get_avg_grade()}"


class Reviever(Mentor):
  def rate_hw(self, student, course, grade):
    student.grades[course] = [grade]

# %%
lecturer_math = Lecturer("Иван", "Петров", {})
lecturer_py = Lecturer("Анна", "Сидорова", {})
lecturer_bio = Lecturer("Сергей", "Иванов", {})

# Прикрепляем лекторов к курсам
lecturer_math.courses_attached.append("Математика")
lecturer_py.courses_attached.append("Python")
lecturer_py.courses_attached.append("Алгоритмы") # Лектор может вести несколько курсов
lecturer_bio.courses_attached.append("Биология")

# Создаем студентов
student1 = Student("Алексей", "Смирнов", "Мужской")
student2 = Student("Елена", "Кузнецова", "Женский")
student3 = Student("Петр", "Васильев", "Мужской")

# Студенты записываются на курсы
student1.add_courses("Математика")
student1.add_courses("Python")
student1.add_finished_courses("Литература")
student2.add_courses("Python")
student2.add_courses("Алгоритмы")
student3.add_courses("Биология")

reviever1 = Reviever('Павел', 'Солнцев')
reviever1.rate_hw(student1, 'Математика', 7)
reviever1.rate_hw(student1, 'Python', 10)
reviever2 = Reviever('Игорь', 'Колесников')


print("\n--- Выставление оценок ---")

# Успешные оценки
student1.rate_lecturer(lecturer_math, "Математика", 9)
student1.rate_lecturer(lecturer_py, "Python", 10)
student2.rate_lecturer(lecturer_py, "Python", 8)
student2.rate_lecturer(lecturer_py, "Алгоритмы", 9)
student3.rate_lecturer(lecturer_bio, "Биология", 7)

print("\n--- Результаты оценок ---")

# Вывод оценок лекторов
print(f"Оценки лектора {lecturer_math.surname}: {lecturer_math.rating}")
print(f"Оценки лектора {lecturer_py.surname}: {lecturer_py.rating}")
print(f"Оценки лектора {lecturer_bio.surname}: {lecturer_bio.rating}")

print("\n--- История оценок студентов ---")
print(f"Оценки студента {student1.surname}: {student1.grades}")
print(f"Оценки студента {student2.surname}: {student2.grades}")
print(f"Оценки студента {student3.surname}: {student3.grades}")

print("\n--- Попытки некорректного выставления оценок ---")

# Попытка поставить оценку за курс, на который студент не записан
student1.rate_lecturer(lecturer_math, "Биология", 5)

# Попытка поставить оценку лектору, который не ведет этот курс
student1.rate_lecturer(lecturer_math, "Python", 6)

# Попытка поставить некорректную оценку
student1.rate_lecturer(lecturer_py, "Python", 15)
# Out:
# --- Выставление оценок ---
# Студент Алексей Смирнов поставил лектору Петров оценку 9 по курсу 'Математика'.
# Студент Алексей Смирнов поставил лектору Сидорова оценку 10 по курсу 'Python'.
# Студент Елена Кузнецова поставил лектору Сидорова оценку 8 по курсу 'Python'.
# Студент Елена Кузнецова поставил лектору Сидорова оценку 9 по курсу 'Алгоритмы'.
# Студент Петр Васильев поставил лектору Иванов оценку 7 по курсу 'Биология'.
#
# --- Результаты оценок ---
# Оценки лектора Петров: {'Математика': [9]}
# Оценки лектора Сидорова: {'Python': [10, 8], 'Алгоритмы': [9]}
# Оценки лектора Иванов: {'Биология': [7]}
#
# --- История оценок студентов ---
# Оценки студента Смирнов: {'Математика': [7], 'Python': [10]}
# Оценки студента Кузнецова: {}
# Оценки студента Васильев: {}
#
# --- Попытки некорректного выставления оценок ---
# Ошибка: Студент Алексей Смирнов не записан на курс 'Биология'.
# Ошибка: Лектор Иван Петров не ведет курс 'Python'.
# Ошибка: Оценка должна быть от 1 до 10.

# %% [markdown]
# ### **3.2. Атрибуты и взаимодействие классов**

# %% [markdown]
# * Реализуйте возможность проставления оценок студентам только Reviewer-ам (реализуйте такой метод).
#
# * Реализуйте метод выставления оценок лекторам у класса Student (оценки по 10-балльной шкале, хранятся в атрибуте-словаре у Lecturer, в котором ключи – названия курсов, а значения – списки оценок). Лектор при этом должен быть закреплен за тем курсом, на который записан студент (реализовать проверку).

# %%
cool_dude = Lecturer('Дмитрий', 'Сафонов', {})
print(cool_dude.name, cool_dude.surname)

cool_mentor = Reviever('Some', 'Buddy')
cool_mentor.rate_hw(best_student, 'Python', 10)

print("Имя студента: ", best_student.name)
print("Имя преподавателя: ", cool_mentor.name)
print("Оценки студента по курсам: ", best_student.grades)
# Out:
# Дмитрий Сафонов
# Имя студента:  Ruoy
# Имя преподавателя:  Some
# Оценки студента по курсам:  {'Python': [10]}

# %% [markdown]
# ### **3.3. Полиморфизм и магические методы**

# %% [markdown]
# Перегрузите магический метод \_\_str__ у всех классов.
# У проверяющих он должен выводить информацию в следующем виде:
#
#
#
# ```
# print(some_reviewer)
# Имя: Some
# Фамилия: Buddy
# ```
#
# У лекторов:
#
#
#
# ```
# print(some_lecturer)
# Имя: Some
# Фамилия: Buddy
# Средняя оценка за лекции: 9.9
# ```
#
# А у студентов так:
#
#
#
# ```
# print(some_student)
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.9
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
# ```

# %%
print(reviever1)
print('\n')
print(lecturer_py)
print('\n')
print(student1)
# Out:
# Имя: Павел
# Фамилия: Солнцев
#
#
# Имя: Анна
# Фамилия: Сидорова
# Средняя оценка за лекции: 9.0
#
#
# Имя: Алексей
# Фамилия: Смирнов
# Средняя оценка за домашние задания: 8.5
# Курсы в процессе изучения: Математика, Python
# Завершенные курсы: Литература

# %% [markdown]
# **Реализуйте перегрузку других магических методов на Ваш выбор (не менее трёх), руководствуясь по смыслу контекстом представленных классов (студенты, преподаватели, оценки и т.д.)**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.courses_in_progress.append(course_name)

    def add_finished_courses(self, course_name):
      self.finished_courses.append(course_name)

    def rate_lecturer(self, lecturer, course_name, rating):

      if course_name not in self.courses_in_progress:
          print(f"Ошибка: Студент {self.name} {self.surname} не записан на курс '{course_name}'.")
          return

      if course_name not in lecturer.courses_attached:
          print(f"Ошибка: Лектор {lecturer.name} {lecturer.surname} не ведет курс '{course_name}'.")
          return

      if not 1 <= rating <= 10:
          print("Ошибка: Оценка должна быть от 1 до 10.")
          return

      if course_name not in lecturer.rating:
          lecturer.rating[course_name] = []

      lecturer.rating[course_name].append(rating)


      print(f"Студент {self.name} {self.surname} поставил лектору {lecturer.surname} оценку {rating} по курсу '{course_name}'.")

    def __str__(self):
      grades_sum = 0
      grades_count = 0
      for course_grades in self.grades.values():
        grades_sum += sum(course_grades)
        grades_count += len(course_grades)

      avg_grades = grades_sum / grades_count if grades_count > 0 else 0.0
      formatted_avg_grades = f"{avg_grades:.1f}"

      courses_in_progress_str = ", ".join(self.courses_in_progress)
      finished_courses_str = ", ".join(self.finished_courses)

      return (f"Имя: {self.name}\n"
              f"Фамилия: {self.surname}\n"
              f"Средняя оценка за домашние задания: {formatted_avg_grades}\n"
              f"Курсы в процессе изучения: {courses_in_progress_str}\n"
              f"Завершенные курсы: {finished_courses_str}")

    def __repr__(self):
      return f'Student({self.name}, {self.surname}, {self.gender})'


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def __str__(self):
      return f'Имя: {self.name}\nФамилия: {self.surname}'

class Lecturer(Mentor):
  def __init__(self, name, surname, rating):
    super().__init__(name, surname)
    self.rating = {}

  def get_avg_grade(self):
    grades_sum = 0
    grades_count = 0
    for course_grades in self.rating.values():
        grades_sum += sum(course_grades)
        grades_count += len(course_grades)

    avg_rating = grades_sum / grades_count if grades_count > 0 else 0.0
    formatted_avg_rating = f"{avg_rating:.1f}"
    return float(formatted_avg_rating)

  def __str__(self):
    return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {self.get_avg_grade()}"

  def __lt__(self, other):
    if not isinstance(other, Lecturer):
      return NotImplemented
    print(f'{self.get_avg_grade()} < {other.get_avg_grade()}')
    return self.get_avg_grade() < other.get_avg_grade()

class Reviever(Mentor):
  def rate_hw(self, student, course, grade):
    student.grades[course] = [grade]

  def __eq__(self, other):

    return type(self) == type(other)

# %% [markdown]
# ### **3.4. Тестирование**
#
# Создайте по 2 экземпляра каждого класса, вызовите все созданные методы, а также реализуйте две функции:
#
# * для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса (в качестве аргументов принимаем список студентов и название курса);
# * для подсчета средней оценки за лекции всех лекторов в рамках курса (в качестве аргумента принимаем список лекторов и название курса).

# %%
def get_average_student_grade(students, course):

    all_grades = []

    for student in students:

        if course in student.grades:
            all_grades.extend(student.grades[course])

    return (
        round(sum(all_grades) / len(all_grades), 1)
        if all_grades else
        0.0
    )


def get_average_lecturer_grade(lecturers, course):
    all_rating = []
    for lecturer in lecturers:

        if course in lecturer.rating:
            all_rating.extend(lecturer.rating[course])

    return (
        round(sum(all_rating) / len(all_rating), 1)
        if all_rating else
        0.0
    )

lecturer_math = Lecturer("Иван", "Петров", {})
lecturer_py1 = Lecturer("Анна", "Сидорова", {})
lecturer_py2 = Lecturer("Виктор", "Сомойлов", {})
lecturer_bio = Lecturer("Сергей", "Иванов", {})

# Прикрепляем лекторов к курсам
lecturer_math.courses_attached.append("Математика")
lecturer_py1.courses_attached.append("Python")
lecturer_py1.courses_attached.append("Алгоритмы") # Лектор может вести несколько курсов
lecturer_py2.courses_attached.append("Python")
lecturer_bio.courses_attached.append("Биология")

# Создаем студентов
student1 = Student("Алексей", "Смирнов", "Мужской")
student2 = Student("Елена", "Кузнецова", "Женский")
student3 = Student("Петр", "Васильев", "Мужской")

# Студенты записываются на курсы
student1.add_courses("Математика")
student1.add_courses("Python")
student1.add_finished_courses("Литература")
student2.add_courses("Python")
student2.add_courses("Алгоритмы")
student3.add_courses("Биология")

reviever1 = Reviever('Павел', 'Солнцев')
reviever1.rate_hw(student1, 'Математика', 7)
reviever1.rate_hw(student1, 'Python', 10)
reviever2 = Reviever('Игорь', 'Колесников')




print("\n--- Выставление оценок ---")

# Успешные оценки
student1.rate_lecturer(lecturer_math, "Математика", 9)
student1.rate_lecturer(lecturer_py1, "Python", 10)
student2.rate_lecturer(lecturer_py2, "Python", 8)
student2.rate_lecturer(lecturer_py, "Алгоритмы", 9)
student3.rate_lecturer(lecturer_bio, "Биология", 7)

print("\n--- Результаты оценок ---")

# Вывод оценок лекторов
print(f"Оценки лектора {lecturer_math.surname}: {lecturer_math.rating}")
print(f"Оценки лектора {lecturer_py.surname}: {lecturer_py.rating}")
print(f"Оценки лектора {lecturer_bio.surname}: {lecturer_bio.rating}")

print("\n--- История оценок студентов ---")
print(f"Оценки студента {student1.surname}: {student1.grades}")
print(f"Оценки студента {student2.surname}: {student2.grades}")
print(f"Оценки студента {student3.surname}: {student3.grades}")

print("\n--- Попытки некорректного выставления оценок ---")

# Попытка поставить оценку за курс, на который студент не записан
student1.rate_lecturer(lecturer_math, "Биология", 5)

# Попытка поставить оценку лектору, который не ведет этот курс
student1.rate_lecturer(lecturer_math, "Python", 6)

# Попытка поставить некорректную оценку
student1.rate_lecturer(lecturer_py, "Python", 15)

students = [student1, student2]
lecturers = [lecturer_py1, lecturer_py2]

avg_students_python = get_average_student_grade(students, "Python")
avg_lecturers_python = get_average_lecturer_grade(lecturers, "Python")
print("\n--------------------------------------------------------")
print(f"Средняя оценка студентов по курсу Python: {avg_students_python}")
print(f"Средняя оценка лекторов по курсу Python: {avg_lecturers_python}")
# Out:
# --- Выставление оценок ---
# Студент Алексей Смирнов поставил лектору Петров оценку 9 по курсу 'Математика'.
# Студент Алексей Смирнов поставил лектору Сидорова оценку 10 по курсу 'Python'.
# Студент Елена Кузнецова поставил лектору Сомойлов оценку 8 по курсу 'Python'.
# Студент Елена Кузнецова поставил лектору Сидорова оценку 9 по курсу 'Алгоритмы'.
# Студент Петр Васильев поставил лектору Иванов оценку 7 по курсу 'Биология'.
#
# --- Результаты оценок ---
# Оценки лектора Петров: {'Математика': [9]}
# Оценки лектора Сидорова: {'Python': [10, 8], 'Алгоритмы': [9, 9, 9, 9]}
# Оценки лектора Иванов: {'Биология': [7]}
#
# --- История оценок студентов ---
# Оценки студента Смирнов: {'Математика': [7], 'Python': [10]}
# Оценки студента Кузнецова: {}
# Оценки студента Васильев: {}
#
# --- Попытки некорректного выставления оценок ---
# Ошибка: Студент Алексей Смирнов не записан на курс 'Биология'.
# Ошибка: Лектор Иван Петров не ведет курс 'Python'.
# Ошибка: Оценка должна быть от 1 до 10.
# ...

# %%
print(lecturer_py < lecturer_bio)
print(repr(student1))
print(reviever1 == reviever2)
print(reviever1 == lecturer_bio)
# Out:
# 9.0 < 7.0
# False
# Student(Алексей, Смирнов, Мужской)
# True
# False

# %% [markdown]
# ## **Задание №4. Перегрузка операторов с помощью магических методов**

# %% [markdown]
# ### **Цель задания:**

# %% [markdown]
# Разработать класс `Fraction` для работы с рациональными числами (дробями), реализовав перегрузку стандартных операторов через переопределение соответствующих магических методов. Ваша задача — обеспечить класс `Fraction` функциональностью, демонстрируемой в приведенном примере кода.

# %% [markdown]
# ### **Описание задания:**

# %% [markdown]
# Создайте класс `Fraction`, который представляет собой обыкновенную дробь с числителем и знаменателем. Перегрузите основные арифметические операторы для выполнения операций над дробями, а также операторы сравнения. Обеспечьте возможность преобразования дроби в число с плавающей точкой и обратную операцию. Реализуйте обработку исключений при некорректных данных. Предоставьте понятное строковое и официальное представление дроби.

# %% [markdown]
# **Требования к заданию:**

# %% [markdown]
# 1. **Класс `Fraction` должен:**
#
#    - Инициализироваться двумя целыми числами: числителем и знаменателем.
#    - Обрабатывать ситуацию когда знаменатель равен нулю, а именно выводить сообщение `"Знаменатель не может быть нулем"`.
#    - Упрощать дроби до несократимых при создании и после каждой арифметической операции.
#
# 2. **Перегрузить следующие операторы путем переопределения магических методов:**
#
#    - **Сложение `+`** (`__add__`): сложение двух дробей, возвращает новую дробь.
#    - **Вычитание `-`** (`__sub__`): вычитание одной дроби из другой, возвращает новую дробь.
#    - **Умножение `*`** (`__mul__`): умножение двух дробей, возвращает новую дробь.
#    - **Деление `/`** (`__truediv__`): деление одной дроби на другую, возвращает новую дробь.
#    - **Равенство `==`** (`__eq__`): проверка равенства двух дробей.
#    - **Сравнения `>`, `<`, `>=`, `<=`**: сравнение дробей по их значению, реализовать методы `__lt__`, `__le__`, `__gt__`, `__ge__`.
#
# 3. **Реализовать преобразование типов:**
#
#    - **Метод `__float__`**: преобразование дроби в число с плавающей точкой.
#
# 4. **Дополнительные методы класса:**
#
#    - **`reciprocal()`**: возвращает новую дробь, обратную данной (числитель и знаменатель меняются местами).
#    - **Строковое представление** (`__str__`): возвращает строку вида `"числитель/знаменатель"`. Если знаменатель равен 1, возвращает только числитель в виде строки.
#    - **Официальное представление** (`__repr__`): возвращает строку вида `"Fraction(числитель, знаменатель)"`.
#
# 5. **Обработка исключений:**
#
#    - При попытке создать дробь с нулевым знаменателем выводить в консоль сообщение `ValueError`.
#    - При попытке деления на нулевую дробь, выводить в консоль сообщение `ZeroDivisionError`.
#
# 6. **Тестирование:**
#
#    - Написать код, демонстрирующий работу всех реализованных методов и операторов, используя примеры, приведенные ниже.
#    - Обеспечить корректную обработку исключений и вывод соответствующих сообщений.

# %%
import math

class Fraction:
  def __init__(self, numerator, denominator):
    if denominator == 0:
      raise ValueError('Знаменатель не может быть нулем')
    self.numerator = numerator
    self.denominator = denominator

    self.simplify(numerator, denominator)

  def gcd(self, a, b):
    return math.gcd(a, b)

  def simplify(self, num, den):
    common_divisor = self.gcd(abs(num), abs(den))
    self.numerator = num // common_divisor
    self.denominator = den // common_divisor

    if self.denominator < 0:
      self.numerator = -self.numerator
      self.denominator = -self.denominator

  def __add__(self, other):
    if isinstance(other, Fraction):
      num = self.numerator * other.denominator + other.numerator * self.denominator
      den = self.denominator * other.denominator
      return Fraction(num, den)
    else:
      raise ValueError('Оба числа должны являться дробью')

  def __sub__(self, other):
    if isinstance(other, Fraction):
      num = self.numerator * other.denominator - other.numerator * self.denominator
      den = self.denominator * other.denominator
      return Fraction(num, den)
    else:
      raise ValueError('Оба числа должны являться дробью')

  def __mul__(self, other):
    if isinstance(other, Fraction):
      num = self.numerator * other.numerator
      den = self.denominator * other.denominator
      return Fraction(num, den)
    else:
      raise ValueError('Оба числа должны являться дробью')

  def __truediv__(self, other):
    if isinstance(other, Fraction):
      if self.denominator == 0 or other.numerator == 0:
        raise ZeroDivisionError()
      else:
        num = self.numerator * other.denominator
        den = self.denominator * other.numerator
        return Fraction(num, den)
    else:
      raise ValueError('Оба числа должны являться дробью')

  def __eq__(self, other):
    if isinstance(other, Fraction):
      self.simplify(self.numerator, self.denominator)
      other.simplify(other.numerator, other.denominator)
      if self.numerator == other.numerator and self.denominator == other.denominator:
        return True
      else:
        return False
    else:
      raise ValueError('Оба числа должны являться дробью')

  def __lt__(self, other):
    if isinstance(other, Fraction):
      num1 = self.numerator * other.denominator
      num2 = other.numerator * self.denominator
      if num1 < num2:
        return True
      else:
        return False
    else:
      raise ValueError('Оба числа должны являться дробью')

  def __le__(self, other):
    if isinstance(other, Fraction):
      num1 = self.numerator * other.denominator
      num2 = other.numerator * self.denominator
      if num1 <= num2:
        return True
      else:
        return False
    else:
      raise ValueError('Оба числа должны являться дробью')

  def __gt__(self, other):
    if isinstance(other, Fraction):
      num1 = self.numerator * other.denominator
      num2 = other.numerator * self.denominator
      if num1 > num2:
        return True
      else:
        return False
    else:
      raise ValueError('Оба числа должны являться дробью')

  def __ge__(self, other):
    if isinstance(other, Fraction):
      num1 = self.numerator * other.denominator
      num2 = other.numerator * self.denominator
      if num1 >= num2:
        return True
      else:
        return False
    else:
      raise ValueError('Оба числа должны являться дробью')

  def from_float(num):
    if isinstance(num, float):
      numerator = num * 10 ** (len(str(num)) - 2)
      return Fraction(int(numerator), 100)
    else:
      raise ValueError('Число должно быть десятичной дробью')

  def __float__(self):
    return self.numerator / self.denominator

  def __str__(self):
    return f'{self.numerator}/{self.denominator}'

  def __repr__(self):
    return f'Fraction({self.numerator}, {self.denominator})'

  def reciprocal(self):
    return Fraction(self.denominator, self.numerator)

# %% [markdown]
# **Тесты для класса `Fraction`:**

# %%
# Создание дробей
f1 = Fraction(3, 4)
f2 = Fraction(5, 6)

print('Сложение дробей')
f3 = f1 + f2
print(f3)  # Ожидаемый вывод: 19/12

print('Вычитание дробей')
f4 = f1 - f2
print(f4)  # Ожидаемый вывод: -1/12

print('Умножение дробей')
f5 = f1 * f2
print(f5)  # Ожидаемый вывод: 5/8

print('Деление дробей')
f6 = f1 / f2
print(f6)  # Ожидаемый вывод: 9/10

print('Проверка равенства')
print(f1 == Fraction(6, 8))   # Ожидаемый вывод: True

print('Сравнение дробей')
print(f1 > f2)    # Ожидаемый вывод: False
print(f1 < f2)    # Ожидаемый вывод: True

print('Преобразование к float')
print(float(f1))  # Ожидаемый вывод: 0.75

print('Обратная дробь')
f7 = f1.reciprocal()
print(f7)         # Ожидаемый вывод: 4/3

print('Создание дроби из float')
f8 = Fraction.from_float(0.75)
print(f8)         # Ожидаемый вывод: 3/4

print('Проверка обработки исключений')
try:
    f_invalid = Fraction(5, 0)
except ValueError as e:
    print(e)  # Ожидаемый вывод: Знаменатель не может быть нулем

print('Строковое и официальное представление')
print(str(f1))    # Ожидаемый вывод: 3/4
print(repr(f1))   # Ожидаемый вывод: Fraction(3, 4)
# Out:
# Сложение дробей
# 19/12
# Вычитание дробей
# -1/12
# Умножение дробей
# 5/8
# Деление дробей
# 9/10
# Проверка равенства
# True
# Сравнение дробей
# False
# True
# Преобразование к float
# 0.75
# Обратная дробь
# 4/3
# Создание дроби из float
# 3/4
# Проверка обработки исключений
# Знаменатель не может быть нулем
# Строковое и официальное представление
# 3/4
# Fraction(3, 4)
